# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib
from sciplots import AnnotatedLinePlot

# %%
plot = AnnotatedLinePlot(figsize=(9, 6))
plot.add_line(range(0, 10), range(0, 10))
plot.show()
# Out:
# /Users/mattfeng/workshops/plotting/sciplots.py:18: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   self.fig.show()
